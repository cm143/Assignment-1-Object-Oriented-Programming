# %%
class Car:
    Manufacturer: str
    Model: str
    Year: int
    Mileage: int
    Engine: str
    Transmission: str
    Drivetrain: str
    Mpg: int or str
    ExtColor: str
    IntColor: str
    Accident: bool
    Price: int
    
    def __init__(self, manufacturer, model, year, mileage, engine, transmission, drivetrain, mpg, extcolor, intcolor, accident, price):
        self.Manufacturer = manufacturer

    
    def PaintJob(self, new_color):
        self.ExtColor = new_color

    def RepairJob(self, part_type, new_part):
        if part_type == "engine":
            self.Engine = new_part
        elif part_type == "transmission":
            self.Transmission = new_part
        elif part_type == "drivetrain":
            self.Drivetrain = new_part
        else:
            print("Please input a valid part.")
            
    def ReupholsterJob(self, intcolor):
        self.IntColor = other_color
        
    def DriveJob(self, mpg):
        self.mpg = mpg + new_mileage

    def PriceJob(self, price):
        if new_price < 1:
            self.Modify_Price = new_price
            price - new_price = new_amount
            print("The new price is "new_amount". Is this correct?")


class Seller:
    Name: str
    Rating: int
    Inventory: int
    
    def __init__(self, name, rating, inventory):
        self.Name = name
    def Buy(self, inventory):
        self.Name = new_car
        for inventory in range(len(inventory)):
            if inventory[inventory] == new_car:
                inventory.append(new_car)

    def Sell(self, inventory):
        self.Name = new_car
        for inventory in range(;en(inventory)):
            if inventory[inventory] == new_car:
                inventory.remove(new_car)
